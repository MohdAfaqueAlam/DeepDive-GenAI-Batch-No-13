# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="phi3:latest")

# %%
response = llm.invoke("What is agentic AI?. describe in 50 words")

# %%
print(response.content)
# Out:
# Agentic Artificial Intelligence (AI) refers to a proactive and purpose-driven form of technology that operates autonomously with minimal human intervention. It self-learns, adapts its behavior based on experiences, and makes informed decisions aligned with predefined objectives or ethical guidelines in various applications like healthcare, security, etc.
#
# Agentic AI exhibits higher levels of autonomy than traditional rule-based systems, constantly seeking to optimize outcomes while maintaining transparency and accountability for its actions through explainable decision-making processes.
